# %%
import pandas as pd
# Out:
# /var/folders/hv/1_92kz110w572ncggsb_c81c0000gp/T/ipykernel_94954/2035458946.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was too old on your system - pyarrow 10.0.1 is the current minimum supported version as of this release.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv("/Users/sebastiencaron/Desktop/Fixed-Income/Cours 6/Trace.csv")
df
# Out:
#          ASCII_RPTD_VOL_TX  ASOF_CD  CUSIP_ID_NUM  MSG_SEQ_NB  \
# 0                  1000000      1.0           476          25
# 1                   500000      NaN           476        8460
# 2                   500000      NaN           476        6281
# 3                   500000      NaN           476       21468
# 4                  2000000      NaN           476        3501
# ...                    ...      ...           ...         ...
# 2667211             377000      NaN        527685       51940
# 2667212             377000      NaN        527685       51941
# 2667213             177000      NaN        527685       36667
# 2667214             100000      NaN        527685       37032
# 2667215             200000      NaN        527685       34094
#
#          ORIG_MSG_SEQ_NB  RATING_1  RATING_2  RATING_3  RPTD_PR  TRC_ST  \
# 0                    NaN       7.0      11.0       7.0  124.637       2
# 1                    NaN       7.0      11.0       7.0  123.952       2
# ...

# %%
tickers = list(df.columns)

# %%
import wrds

# %%
conn = wrds.Connection()
# Out:
# WRDS recommends setting up a .pgpass file.
# Created .pgpass file successfully.
# You can create this file yourself at any time with the create_pgpass_file() function.
# Loading library list...
# Done

# %%
def finder_list(sorting : str, list_tosort : list) -> list :
    return [i for i in list_tosort if i.startswith(sorting)]



lib_available = conn.list_libraries()

finder_list("comp", lib_available)
# Out:
# ['comp',
#  'comp_execucomp',
#  'comp_global',
#  'comp_global_daily',
#  'comp_na_annual_all',
#  'comp_na_daily_all',
#  'comp_na_monthly_all',
#  'compa',
#  'compg',
#  'compm',
#  'compsamp',
#  'compsamp_all',
#  'compsamp_snapshot']

# %%
finder_list("fun", conn.list_tables(library='comp'))
# Out:
# ['funda', 'funda_fncd', 'fundq', 'fundq_fncd']

# %%
conn.get_table(library="comp", table="funda")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/sebastiencaron/Desktop/Fixed-Income/Cours 6/data.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/sebastiencaron/Desktop/Fixed-Income/Cours%206/data.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> conn.get_table(library="comp", table="funda")
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/wrds/sql.py:649, in Connection.get_table(self, library, table, obs, offset, columns, coerce_float, index_col, date_cols)
#     639 if self.__check_schema_perms(library):
#     640     sqlstmt = (
#     641         "SELECT {cols} FROM {schema}.{table} {obsstmt} OFFSET {offset};".format(
#     642             cols=cols,
#    (...)
#     647         )
#     648     )
# --> 649     return self.raw_sql(
#     650         sqlstmt,
#     651         coerce_float=coerce_float,
# ...
